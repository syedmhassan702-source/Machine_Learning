# %%
import pandas as pd

# %%
df = pd.read_csv("data_for_ml.csv")

# %%
df
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage  Gender Study_Method  \
# 0             2.0          6.0             3.0    Male   Self Study
# 1             3.0          7.0             2.0  Female     Coaching
# 2             4.0          6.0             4.0    male   Self study
# 3             5.0          8.0             3.0   Femle  Group Study
# 4             6.0          7.0             5.0    Male   Self Study
# 5             7.0          6.0             6.0  Female     coaching
# 6             8.0          7.0             4.0    Male  Group study
# 7             2.0          5.0             7.0  Female   Self Study
# 8             3.0          6.0             6.0    Male   Self Study
# 9             4.0          7.0             5.0  Female  Group Study
# 10            5.0          8.0             4.0    Male   Self Study
# 11            6.0          6.0             5.0  Female     Coaching
# 12            7.0          7.0             6.0    Male   Self study
# 13            8.0          8.0             3.0  Female  Group Study
# 14            NaN          7.0             4.0    Male   Self Study
# 15            5.0          NaN             5.0  Female     Coaching
# 16            6.0          6.0             NaN    Male  Group Study
# 17            7.0          7.0             6.0     NaN   Self Study
# 18            8.0          8.0             3.0  Female          NaN
# 19            4.0          6.0             5.0    Male   Self Study
# 20            3.0          5.0             6.0  Female     Coaching
# 21            2.0          6.0             7.0    Male   Self Study
# 22            5.0          8.0             4.0  Female  Group Study
# 23            6.0          7.0             5.0    Male   Self Study
# 24            7.0          6.0             6.0  Female     Coaching
# 25            8.0          7.0             4.0    Male  Group Study
# 26            2.0          5.0             7.0  Female   Self Study
# 27            3.0          6.0             6.0    Male   Self Study
# 28            4.0          7.0             5.0  Female  Group Study
# 29            5.0          8.0             4.0    Male   Self Study
# 30            6.0          6.0             5.0  Female     Coaching
# 31            7.0          7.0             6.0    Male   Self Study
# 32            8.0          8.0             3.0  Female  Group Study
# 33            2.0          6.0             3.0    Male   Self Study
# 34            3.0          7.0             2.0  Female     Coaching
# 35            4.0          6.0             4.0    male   Self study
# 36            5.0          8.0             3.0   Femle  Group Study
# 37            6.0          7.0             5.0    Male   Self Study
# 38            7.0          6.0             6.0  Female     coaching
# 39            8.0          7.0             4.0    Male  Group study
# 40            2.0          5.0             7.0  Female   Self Study
# 41            3.0          6.0             6.0    Male   Self Study
# 42            4.0          7.0             5.0  Female  Group Study
# 43            5.0          8.0             4.0    Male   Self Study
# 44            6.0          6.0             5.0  Female     Coaching
# 45            7.0          7.0             6.0    Male   Self study
# 46            8.0          8.0             3.0  Female  Group Study
# 47            1.0          5.0             8.0    Male   Self Study
# 48            9.0          8.0             2.0  Female     Coaching
# 49           10.0          7.0             1.0    Male   Self Study
# 50            1.0          4.0             9.0  Female  Group Study
# 51            9.0          9.0             2.0    Male   Self Study
# 52           10.0          8.0             1.0  Female     Coaching
# 53            3.0          6.0             6.0    Male   Self Study
# 54            3.0          6.0             6.0    Male   Self Study
# 55            4.0          7.0             5.0  Female  Group Study
# 56            4.0          7.0             5.0  Female  Group Study
#
#     Attendance  Final_Score
# 0         75.0         55.0
# 1         80.0         60.0
# 2         78.0         62.0
# 3         85.0         70.0
# 4         88.0         72.0
# 5         90.0         75.0
# 6         92.0         80.0
# 7         70.0         50.0
# 8         75.0         55.0
# 9         82.0         65.0
# 10        85.0         68.0
# 11        88.0         72.0
# 12        90.0         76.0
# 13        95.0         85.0
# 14        80.0         65.0
# 15        85.0         70.0
# 16        88.0         72.0
# 17        90.0         75.0
# 18        92.0         80.0
# 19         NaN         60.0
# 20        78.0          NaN
# 21        70.0         52.0
# 22        85.0         68.0
# 23        88.0         72.0
# 24        90.0         75.0
# 25        92.0         80.0
# 26        70.0         50.0
# 27        75.0         55.0
# 28        82.0         65.0
# 29        85.0         68.0
# 30        88.0         72.0
# 31        90.0         76.0
# 32        95.0         85.0
# 33        75.0         55.0
# 34        80.0         60.0
# 35        78.0         62.0
# 36        85.0         70.0
# 37        88.0         72.0
# 38        90.0         75.0
# 39        92.0         80.0
# 40        70.0         50.0
# 41        75.0         55.0
# 42        82.0         65.0
# 43        85.0         68.0
# 44        88.0         72.0
# 45        90.0         76.0
# 46        95.0         85.0
# 47        65.0         45.0
# 48        96.0         88.0
# 49        98.0         92.0
# 50        60.0         40.0
# 51        97.0         90.0
# 52        99.0         94.0
# 53        75.0         55.0
# 54        75.0         55.0
# 55        82.0         65.0
# 56        82.0         65.0

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.isna().sum()
# Out:
# Hours_Studied     1
# Sleep_Hours       1
# Internet_Usage    1
# Gender            1
# Study_Method      1
# Attendance        1
# Final_Score       1
# dtype: int64

# %%
df["Hours_Studied"] = df["Hours_Studied"].fillna(df["Hours_Studied"].median())

# %%
df["Sleep_Hours"] = df["Sleep_Hours"].fillna(df["Sleep_Hours"].median())

# %%
df["Internet_Usage"] = df["Internet_Usage"].fillna(df["Internet_Usage"].median())

# %%
df["Gender"] = df["Gender"].fillna(df['Gender'].mode()[0])

# %%
df["Study_Method"] = df["Study_Method"].fillna(df['Study_Method'].mode()[0])

# %%
df["Attendance"] = df["Attendance"].fillna(df["Attendance"].median())

# %%
df["Final_Score"] = df["Final_Score"].fillna(df["Final_Score"].median())

# %%
df.isna().sum()
# Out:
# Hours_Studied     0
# Sleep_Hours       0
# Internet_Usage    0
# Gender            0
# Study_Method      0
# Attendance        0
# Final_Score       0
# dtype: int64

# %%
df.dtypes
# Out:
# Hours_Studied     float64
# Sleep_Hours       float64
# Internet_Usage    float64
# Gender             object
# Study_Method       object
# Attendance        float64
# Final_Score       float64
# dtype: object

# %%
df[['Hours_Studied','Sleep_Hours','Internet_Usage','Attendance','Final_Score']] = df[['Hours_Studied','Sleep_Hours','Internet_Usage','Attendance','Final_Score']].astype(int)

# %%
df.dtypes
# Out:
# Hours_Studied      int64
# Sleep_Hours        int64
# Internet_Usage     int64
# Gender            object
# Study_Method      object
# Attendance         int64
# Final_Score        int64
# dtype: object

# %%
df
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage  Gender Study_Method  \
# 0               2            6               3    Male   Self Study
# 1               3            7               2  Female     Coaching
# 2               4            6               4    male   Self study
# 3               5            8               3   Femle  Group Study
# 4               6            7               5    Male   Self Study
# 5               7            6               6  Female     coaching
# 6               8            7               4    Male  Group study
# 7               2            5               7  Female   Self Study
# 8               3            6               6    Male   Self Study
# 9               4            7               5  Female  Group Study
# 10              5            8               4    Male   Self Study
# 11              6            6               5  Female     Coaching
# 12              7            7               6    Male   Self study
# 13              8            8               3  Female  Group Study
# 14              5            7               4    Male   Self Study
# 15              5            7               5  Female     Coaching
# 16              6            6               5    Male  Group Study
# 17              7            7               6  Female   Self Study
# 18              8            8               3  Female   Self Study
# 19              4            6               5    Male   Self Study
# 20              3            5               6  Female     Coaching
# 21              2            6               7    Male   Self Study
# 22              5            8               4  Female  Group Study
# 23              6            7               5    Male   Self Study
# 24              7            6               6  Female     Coaching
# 25              8            7               4    Male  Group Study
# 26              2            5               7  Female   Self Study
# 27              3            6               6    Male   Self Study
# 28              4            7               5  Female  Group Study
# 29              5            8               4    Male   Self Study
# 30              6            6               5  Female     Coaching
# 31              7            7               6    Male   Self Study
# 32              8            8               3  Female  Group Study
# 33              2            6               3    Male   Self Study
# 34              3            7               2  Female     Coaching
# 35              4            6               4    male   Self study
# 36              5            8               3   Femle  Group Study
# 37              6            7               5    Male   Self Study
# 38              7            6               6  Female     coaching
# 39              8            7               4    Male  Group study
# 40              2            5               7  Female   Self Study
# 41              3            6               6    Male   Self Study
# 42              4            7               5  Female  Group Study
# 43              5            8               4    Male   Self Study
# 44              6            6               5  Female     Coaching
# 45              7            7               6    Male   Self study
# 46              8            8               3  Female  Group Study
# 47              1            5               8    Male   Self Study
# 48              9            8               2  Female     Coaching
# 49             10            7               1    Male   Self Study
# 50              1            4               9  Female  Group Study
# 51              9            9               2    Male   Self Study
# 52             10            8               1  Female     Coaching
# 53              3            6               6    Male   Self Study
# 54              3            6               6    Male   Self Study
# 55              4            7               5  Female  Group Study
# 56              4            7               5  Female  Group Study
#
#     Attendance  Final_Score
# 0           75           55
# 1           80           60
# 2           78           62
# 3           85           70
# 4           88           72
# 5           90           75
# 6           92           80
# 7           70           50
# 8           75           55
# 9           82           65
# 10          85           68
# 11          88           72
# 12          90           76
# 13          95           85
# 14          80           65
# 15          85           70
# 16          88           72
# 17          90           75
# 18          92           80
# 19          85           60
# 20          78           69
# 21          70           52
# 22          85           68
# 23          88           72
# 24          90           75
# 25          92           80
# 26          70           50
# 27          75           55
# 28          82           65
# 29          85           68
# 30          88           72
# 31          90           76
# 32          95           85
# 33          75           55
# 34          80           60
# 35          78           62
# 36          85           70
# 37          88           72
# 38          90           75
# 39          92           80
# 40          70           50
# 41          75           55
# 42          82           65
# 43          85           68
# 44          88           72
# 45          90           76
# 46          95           85
# 47          65           45
# 48          96           88
# 49          98           92
# 50          60           40
# 51          97           90
# 52          99           94
# 53          75           55
# 54          75           55
# 55          82           65
# 56          82           65

# %%
df[df.duplicated()]
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage  Gender Study_Method  \
# 23              6            7               5    Male   Self Study
# 26              2            5               7  Female   Self Study
# 27              3            6               6    Male   Self Study
# 28              4            7               5  Female  Group Study
# 29              5            8               4    Male   Self Study
# 30              6            6               5  Female     Coaching
# 32              8            8               3  Female  Group Study
# 33              2            6               3    Male   Self Study
# 34              3            7               2  Female     Coaching
# 35              4            6               4    male   Self study
# 36              5            8               3   Femle  Group Study
# 37              6            7               5    Male   Self Study
# 38              7            6               6  Female     coaching
# 39              8            7               4    Male  Group study
# 40              2            5               7  Female   Self Study
# 41              3            6               6    Male   Self Study
# 42              4            7               5  Female  Group Study
# 43              5            8               4    Male   Self Study
# 44              6            6               5  Female     Coaching
# 45              7            7               6    Male   Self study
# 46              8            8               3  Female  Group Study
# 53              3            6               6    Male   Self Study
# 54              3            6               6    Male   Self Study
# 55              4            7               5  Female  Group Study
# 56              4            7               5  Female  Group Study
#
#     Attendance  Final_Score
# 23          88           72
# 26          70           50
# 27          75           55
# 28          82           65
# 29          85           68
# 30          88           72
# 32          95           85
# 33          75           55
# 34          80           60
# 35          78           62
# 36          85           70
# 37          88           72
# 38          90           75
# 39          92           80
# 40          70           50
# 41          75           55
# 42          82           65
# 43          85           68
# 44          88           72
# 45          90           76
# 46          95           85
# 53          75           55
# 54          75           55
# 55          82           65
# 56          82           65

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     Hours_Studied  Sleep_Hours  Internet_Usage  Gender Study_Method  \
# 0               2            6               3    Male   Self Study
# 1               3            7               2  Female     Coaching
# 2               4            6               4    male   Self study
# 3               5            8               3   Femle  Group Study
# 4               6            7               5    Male   Self Study
# 5               7            6               6  Female     coaching
# 6               8            7               4    Male  Group study
# 7               2            5               7  Female   Self Study
# 8               3            6               6    Male   Self Study
# 9               4            7               5  Female  Group Study
# 10              5            8               4    Male   Self Study
# 11              6            6               5  Female     Coaching
# 12              7            7               6    Male   Self study
# 13              8            8               3  Female  Group Study
# 14              5            7               4    Male   Self Study
# 15              5            7               5  Female     Coaching
# 16              6            6               5    Male  Group Study
# 17              7            7               6  Female   Self Study
# 18              8            8               3  Female   Self Study
# 19              4            6               5    Male   Self Study
# 20              3            5               6  Female     Coaching
# 21              2            6               7    Male   Self Study
# 22              5            8               4  Female  Group Study
# 24              7            6               6  Female     Coaching
# 25              8            7               4    Male  Group Study
# 31              7            7               6    Male   Self Study
# 47              1            5               8    Male   Self Study
# 48              9            8               2  Female     Coaching
# 49             10            7               1    Male   Self Study
# 50              1            4               9  Female  Group Study
# 51              9            9               2    Male   Self Study
# 52             10            8               1  Female     Coaching
#
#     Attendance  Final_Score
# 0           75           55
# 1           80           60
# 2           78           62
# 3           85           70
# 4           88           72
# 5           90           75
# 6           92           80
# 7           70           50
# 8           75           55
# 9           82           65
# 10          85           68
# 11          88           72
# 12          90           76
# 13          95           85
# 14          80           65
# 15          85           70
# 16          88           72
# 17          90           75
# 18          92           80
# 19          85           60
# 20          78           69
# 21          70           52
# 22          85           68
# 24          90           75
# 25          92           80
# 31          90           76
# 47          65           45
# 48          96           88
# 49          98           92
# 50          60           40
# 51          97           90
# 52          99           94

# %%
from sklearn.preprocessing import LabelEncoder

# %%
r2 = df.Study_Method

# %%
le_study = LabelEncoder()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # HOURS_STUDIED

# %%
X = df[['Hours_Studied']]
y = df['Final_Score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Hours_Studied")
MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
R2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error :{MAE} ")
print(f"Mean Squared Error :{MSE} ")
print(f"R2 Svore: {R2}")
# Out:
# Hours_Studied
# Mean Absolute Error :2.769346405228758
# Mean Squared Error :11.019363279080713
# R2 Svore: 0.9431874444262698

# %%
results = pd.DataFrame({
    "Actual": y_test,
    "Predicted": y_pred
})

print(results.head(10))
# Out:
#     Actual  Predicted
# 50      40  48.033333
# 15      70  67.533987
# 25      80  82.159477
# 17      75  77.284314
# 8       55  57.783660
# 9       65  62.658824
# 51      90  87.034641
# 31      76  77.284314
# 12      76  77.284314
# 0       55  52.908497
